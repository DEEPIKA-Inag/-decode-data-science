# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv") #read the csv file

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[["Name", "Age"]] # acess the columns
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.size # find the size
# Out:
# 10692

# %%
df.isnull # check, there is null values or not
# Out:
# <bound method DataFrame.isnull of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.isnull().sum() # check the number of missing value
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(0) # fill the missing values with 0
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated() # check the duplicate value
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.sort_values(["Pclass","Survived","Age","SibSp","Fare","PassengerId"], ascending=False)#descending order
# Out:
#      PassengerId  Survived  Pclass  \
# 483          484         1       3
# 338          339         1       3
# 414          415         1       3
# 400          401         1       3
# 25            26         1       3
# ..           ...       ...     ...
# 711          712         0       1
# 284          285         0       1
# 168          169         0       1
# 815          816         0       1
# 633          634         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 483                             Turkula, Mrs. (Hedwig)  female  63.0      0
# 338                              Dahl, Mr. Karl Edwart    male  45.0      0
# 414                          Sundman, Mr. Johan Julian    male  44.0      0
# 400                                 Niskanen, Mr. Juha    male  39.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.reset_index(drop=True ,inplace=True) #reset the index and drop the old index

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[["Name","Age","Sex","Ticket","Survived","Embarked","Pclass","SibSp",'PassengerId']]
# Out:
#                                                   Name   Age     Sex  \
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
#                Ticket  Survived Embarked  Pclass  SibSp  PassengerId
# 0           A/5 21171         0        S       3      1            1
# ...

# %%
print(df.columns) # find the columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["Age","Cabin"]] =df[["Age","Cabin"]].fillna(0) # fill the Nan values with zero, beacuse we want to convert the decimal value into integer value and nan is not the decimal value

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Age"] =df["Age"].astype(int) # convert the age column into the integer

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df=df[["Name","Age","Sex","Ticket","Survived","Embarked","Pclass","SibSp",'PassengerId']] # reorder the columns

# %%
df
# Out:
#                                                   Name  Age     Sex  \
# 0                              Braund, Mr. Owen Harris   22    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38  female
# 2                               Heikkinen, Miss. Laina   26  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35  female
# 4                             Allen, Mr. William Henry   35    male
# ..                                                 ...  ...     ...
# 886                              Montvila, Rev. Juozas   27    male
# 887                       Graham, Miss. Margaret Edith   19  female
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  female
# 889                              Behr, Mr. Karl Howell   26    male
# 890                                Dooley, Mr. Patrick   32    male
#
#                Ticket  Survived Embarked  Pclass  SibSp  PassengerId
# 0           A/5 21171         0        S       3      1            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         891 non-null    object
#  1   Age          891 non-null    int32
#  2   Sex          891 non-null    object
#  3   Ticket       891 non-null    object
#  4   Survived     891 non-null    int64
#  5   Embarked     889 non-null    object
#  6   Pclass       891 non-null    int64
#  7   SibSp        891 non-null    int64
#  8   PassengerId  891 non-null    int64
# dtypes: int32(1), int64(4), object(4)
# memory usage: 59.3+ KB

# %%
df
# Out:
#                                                   Name  Age     Sex  \
# 0                              Braund, Mr. Owen Harris   22    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38  female
# 2                               Heikkinen, Miss. Laina   26  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35  female
# 4                             Allen, Mr. William Henry   35    male
# ..                                                 ...  ...     ...
# 886                              Montvila, Rev. Juozas   27    male
# 887                       Graham, Miss. Margaret Edith   19  female
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  female
# 889                              Behr, Mr. Karl Howell   26    male
# 890                                Dooley, Mr. Patrick   32    male
#
#                Ticket  Survived Embarked  Pclass  SibSp  PassengerId
# 0           A/5 21171         0        S       3      1            1
# ...

# %%
df.loc[df['Embarked'] == 'C', 'Embarked'] = 'Cherbourg'
df.loc[df['Embarked'] == 'Q', 'Embarked'] = 'Queenstown'
df.loc[df['Embarked'] == 'S', 'Embarked'] = 'Southampton'

# %%
df
# Out:
#                                                   Name  Age     Sex  \
# 0                              Braund, Mr. Owen Harris   22    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38  female
# 2                               Heikkinen, Miss. Laina   26  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35  female
# 4                             Allen, Mr. William Henry   35    male
# ..                                                 ...  ...     ...
# 886                              Montvila, Rev. Juozas   27    male
# 887                       Graham, Miss. Margaret Edith   19  female
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  female
# 889                              Behr, Mr. Karl Howell   26    male
# 890                                Dooley, Mr. Patrick   32    male
#
#                Ticket  Survived     Embarked  Pclass  SibSp  PassengerId
# 0           A/5 21171         0  Southampton       3      1            1
# ...

# %%
df.drop(["PassengerId","Pclass","Ticket"], axis=1,inplace =True)
# Out:
# C:\Users\svjic\AppData\Local\Temp\ipykernel_3360\2524312330.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["PassengerId","Pclass","Ticket"], axis=1,inplace =True)

# %%
df
# Out:
#                                                   Name  Age     Sex  Survived  \
# 0                              Braund, Mr. Owen Harris   22    male         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38  female         1
# 2                               Heikkinen, Miss. Laina   26  female         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35  female         1
# 4                             Allen, Mr. William Henry   35    male         0
# ..                                                 ...  ...     ...       ...
# 886                              Montvila, Rev. Juozas   27    male         0
# 887                       Graham, Miss. Margaret Edith   19  female         1
# 888           Johnston, Miss. Catherine Helen "Carrie"    0  female         0
# 889                              Behr, Mr. Karl Howell   26    male         1
# 890                                Dooley, Mr. Patrick   32    male         0
#
#         Embarked  SibSp
# ...

# %% [markdown]
# > hence data is clean<
