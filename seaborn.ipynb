# %%
import seaborn as sns 
import numpy as np

# %%
sns.set_theme(style="darkgrid")

# %%
x = np.array([1,2,3,4,5,6,745,65,78,89,76,32,22,90,30])

# %%
y = np.sin(x)

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
